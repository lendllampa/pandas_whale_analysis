# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
whale_csv = ("Starter_Code/Resources/whale_returns.csv")

# %%
# Reading whale returns
whale_df = pd.read_csv(whale_csv, parse_dates=True, infer_datetime_format=True, index_col="Date")
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna(inplace=True)
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
whale_df.dtypes
# Out:
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# dtype: object

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
algocsv = ("Starter_Code/Resources/algo_returns.csv")

# %%
# Reading algorithmic returns
algo_df = pd.read_csv(algocsv, parse_dates=True, infer_datetime_format=True, index_col="Date")
algo_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df.dropna(inplace=True)
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
algo_df.dtypes
# Out:
# Algo 1    float64
# Algo 2    float64
# dtype: object

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
tsx_csv = ('Starter_Code/Resources/sp_tsx_history.csv')

# %%
# Reading S&P TSX 60 Closing Prices
tsx_df = pd.read_csv(tsx_csv, parse_dates=True, infer_datetime_format=True, index_col="Date")
tsx_df.head()
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99

# %%
# Check Data Types
tsx_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Remove '$' sign and other characters and convert Data Types
tsx_df['Close'] = tsx_df['Close'].str.replace('$', "")
tsx_df['Close'] = tsx_df['Close'].str.replace(',', "")

tsx_df["Close"] = tsx_df["Close"].astype("float")
tsx_df.dtypes

tsx_df.head()
# Out:
# C:\Users\Lendl\anaconda3\envs\alpacaenv\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#                Close
# Date
# 2012-10-01  12370.19
# 2012-10-02  12391.23
# 2012-10-03  12359.47
# 2012-10-04  12447.68
# 2012-10-05  12418.99

# %%
# Calculate Daily Returns
tsx_df['Close'] = tsx_df['Close'].pct_change()

# %%
# Drop nulls
tsx_df.dropna(inplace=True)

# %%
# Rename `Close` Column to be specific to this portfolio
tsx_df = tsx_df.rename(columns={'Close':"S&P/TSX60"})
tsx_df.isnull().sum()
# Out:
# S&P/TSX60    0
# dtype: int64

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
combined_returns = pd.concat(
    [whale_df, algo_df, tsx_df], axis="columns", join="inner"
)

combined_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_returns.plot(figsize=(15,8), title="Portfolio Daily Returns").legend(loc=3, prop={'size': 10})

# %%
# Calculate cumulative returns of all portfolios
port_cumulative_returns = (1+combined_returns).cumprod()
# Plot cumulative returns
port_cumulative_returns.plot(figsize=(10,7), title="Portfolio Cumulative Returns").legend(loc=2, prop={'size': 9})

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_returns.plot.box(figsize=(21,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
all_portfolio_std = combined_returns.std()
all_portfolio_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# S&P/TSX60                      0.007034
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
tsx_std = combined_returns["S&P/TSX60"].std()
tsx_std
# Out:
# 0.007034167748577725

# %%
# Create dataframe for all portfolios standard deviations
portfolio_std_df = pd.DataFrame(all_portfolio_std, columns=["Std"])
portfolio_std_df
# Out:
#                                   Std
# SOROS FUND MANAGEMENT LLC    0.007828
# PAULSON & CO.INC.            0.006982
# TIGER GLOBAL MANAGEMENT LLC  0.010883
# BERKSHIRE HATHAWAY INC       0.012826
# Algo 1                       0.007589
# Algo 2                       0.008326
# S&P/TSX60                    0.007034

# %%
# Determine which portfolios are riskier than the S&P TSX 60
tsx = portfolio_std_df.loc["S&P/TSX60", "Std"]
riskier_portfolio = portfolio_std_df[portfolio_std_df["Std"] > tsx]
riskier_portfolio
# Out:
#                                   Std
# SOROS FUND MANAGEMENT LLC    0.007828
# TIGER GLOBAL MANAGEMENT LLC  0.010883
# BERKSHIRE HATHAWAY INC       0.012826
# Algo 1                       0.007589
# Algo 2                       0.008326

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annual_std = all_portfolio_std * np.sqrt(252)
annual_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# Algo 1                         0.120470
# Algo 2                         0.132177
# S&P/TSX60                      0.111664
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P TSX 60 using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_21sma_std = combined_returns.rolling(window=21).std()
# Plot the rolling standard deviation
combined_21sma_std.plot(figsize=(20,10)).legend(loc=2, prop={'size': 11})

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
portfolio_correlation = combined_returns.corr()
portfolio_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.697076
# PAULSON & CO.INC.                             0.697076            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.560964            0.433034
# BERKSHIRE HATHAWAY INC                        0.750181            0.540033
# Algo 1                                        0.313795            0.266363
# Algo 2                                        0.826667            0.674015
# S&P/TSX60                                     0.673930            0.486511
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.560964
# PAULSON & CO.INC.                               0.433034
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.423524
# Algo 1                                          0.161236
# ...

# %%
# Display the correlation matrix
sns.heatmap(portfolio_correlation, vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The portfolio that is the most correlated to the S&P/TSX60 is Algo 2.
# While the least correlated portfolio to the S&P/TSX60 is Algo 1.

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
rolling_algo1_covariance = combined_returns["Algo 1"].rolling(window=60).cov(combined_returns["S&P/TSX60"])
# Calculate variance of S&P TSX
rolling_tsx_variance = combined_returns["S&P/TSX60"].rolling(60).var()
# Computing beta
algo1_rolling_beta = (rolling_algo1_covariance / rolling_tsx_variance)
# Plot beta trend
algo1_rolling_beta.plot(figsize=(10,7), title="60-Day Rolling Beta of Algo 1")
# Out:
# <AxesSubplot:title={'center':'60-Day Rolling Beta of Algo 1'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
algo_21ema = combined_returns.ewm(halflife=21, adjust=True).std()
algo_21ema.plot(figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
annual_avg_return = combined_returns.mean()*252
sharpe_ratio =  annual_avg_return / annual_std
annual_avg_return
# Out:
# SOROS FUND MANAGEMENT LLC      0.035626
# PAULSON & CO.INC.             -0.060696
# TIGER GLOBAL MANAGEMENT LLC   -0.024956
# BERKSHIRE HATHAWAY INC         0.095090
# Algo 1                         0.179682
# Algo 2                         0.052450
# S&P/TSX60                      0.021836
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot(kind="bar", figsize=(5,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.

# %% [markdown]
# Based on the analysis, the algorithmic strategies both outperforms the S&P TSX 60. The algo strategies are riskier, with a standard deviation of 0.007589 and 0.008326 for Algo 1 and Algo 2, respectively, compared to the standard deviation of the market at 0.007034. Algo 1 in particular is the better algorithmic strategy as it outperforms Algo 2 in Annual Average Return. In fact, Algo 1's Annual Average Return outperforms every other portfolio. It has the highest Sharpe Ratio and doesn't carry as much risk as some of the Whale Porfolios.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P TSX 60 index.
#
# * `SHOP` - [Shopify Inc](https://en.wikipedia.org/wiki/Shopify)
#
# * `OTEX` - [Open Text Corporation](https://en.wikipedia.org/wiki/OpenText)
#
# * `L` - [Loblaw Companies Limited](https://en.wikipedia.org/wiki/Loblaw_Companies)

# %%
# Reading data from 1st stock
shopcsv = ("Starter_Code/Resources/shop_historical.csv")
shop_df = pd.read_csv(shopcsv, parse_dates=True, infer_datetime_format=True, index_col="Date")
shop_df.head()

# Drop symbol and rename 'Close'
shop_df.drop(["Symbol"], axis=1, inplace=True)
shop_df.rename(columns={"Close" : "SHOP"}, inplace=True)
shop_df.head()
# Out:
#               SHOP
# Date
# 2018-01-02  132.06
# 2018-01-03  135.15
# 2018-01-04  137.46
# 2018-01-05  137.26
# 2018-01-08  139.51

# %%
# Reading data from 2nd stock
otexcsv = ("Starter_Code/Resources/otex_historical.csv")
otex_df = pd.read_csv(otexcsv, parse_dates=True, infer_datetime_format=True, index_col="Date")
otex_df.head()

# Drop symbol and rename 'Close'
otex_df.drop(["Symbol"], axis=1, inplace=True)
otex_df.rename(columns={"Close" : "OTEX"}, inplace=True)
otex_df.head()
# Out:
#              OTEX
# Date
# 2018-01-02  43.58
# 2018-01-03  43.07
# 2018-01-04  42.91
# 2018-01-05  42.57
# 2018-01-08  42.16

# %%
# Reading data from 3rd stock
loblawcsv = ("Starter_Code/Resources/l_historical.csv")
loblaw_df = pd.read_csv(loblawcsv, parse_dates=True, infer_datetime_format=True, index_col="Date")
loblaw_df.head()

# Drop symbol and rename 'Close'
loblaw_df.drop(["Symbol"], axis=1, inplace=True)
loblaw_df.rename(columns={"Close" : "L"}, inplace=True)
loblaw_df.head()
# Out:
#                 L
# Date
# 2018-01-02  57.99
# 2018-01-03  57.41
# 2018-01-04  57.42
# 2018-01-05  57.42
# 2018-01-08  56.86

# %%
# Reading data from 4th stock
tslacsv = "Starter_Code/Resources/TSLA.csv"
tsla_df = pd.read_csv(tslacsv, parse_dates=True, infer_datetime_format=True, index_col="Date")
tsla_df.head()

# Drop excess columns and rename 'Close'
tsla_df.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
tsla_df.rename(columns={'Close':'TSLA'}, inplace=True)
tsla_df = tsla_df.round(2)
tsla_df.head()
# Out:
#              TSLA
# Date
# 2015-03-03  39.91
# 2015-03-04  40.49
# 2015-03-05  40.13
# 2015-03-06  38.78
# 2015-03-09  38.18

# %%
# Reading data from 5th stock
aaplcsv = "Starter_Code/Resources/AAPL.csv"
aapl_df = pd.read_csv(aaplcsv, parse_dates=True, infer_datetime_format=True, index_col="Date")
aapl_df.head()

# Drop excess columns and rename 'Close'
aapl_df.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
aapl_df.rename(columns={'Close':"AAPL"},inplace=True)
aapl_df = aapl_df.round(2)
aapl_df.head()
# Out:
#              AAPL
# Date
# 2015-03-03  32.34
# 2015-03-04  32.13
# 2015-03-05  31.60
# 2015-03-06  31.65
# 2015-03-09  31.78

# %%
# Combine all stocks in a single DataFrame
my_portfolio_df = pd.concat([shop_df, otex_df, loblaw_df, tsla_df, aapl_df], axis="columns", join="inner")
my_portfolio_df.head(10)
# Out:
#               SHOP   OTEX      L   TSLA   AAPL
# Date
# 2018-01-02  132.06  43.58  57.99  64.11  43.06
# 2018-01-03  135.15  43.07  57.41  63.45  43.06
# 2018-01-04  137.46  42.91  57.42  62.92  43.26
# 2018-01-05  137.26  42.57  57.42  63.32  43.75
# 2018-01-08  139.51  42.16  56.86  67.28  43.59
# 2018-01-09  137.94  42.13  57.37  66.74  43.58
# 2018-01-10  139.29  41.99  57.09  66.96  43.57
# 2018-01-11  139.14  42.29  56.78  67.59  43.82
# 2018-01-12  140.76  42.17  56.97  67.24  44.27
# 2018-01-16  139.13  41.74  57.45  68.01  44.05

# %%
# Calculate daily returns
my_portfolio_daily_returns = my_portfolio_df.pct_change()
# Drop NAs
my_portfolio_daily_returns.dropna(inplace=True)
# Display sample data
my_portfolio_daily_returns.head(10)
# Out:
#                 SHOP      OTEX         L      TSLA      AAPL
# Date
# 2018-01-03  0.023398 -0.011703 -0.010002 -0.010295  0.000000
# 2018-01-04  0.017092 -0.003715  0.000174 -0.008353  0.004645
# 2018-01-05 -0.001455 -0.007924  0.000000  0.006357  0.011327
# 2018-01-08  0.016392 -0.009631 -0.009753  0.062539 -0.003657
# 2018-01-09 -0.011254 -0.000712  0.008969 -0.008026 -0.000229
# 2018-01-10  0.009787 -0.003323 -0.004881  0.003296 -0.000229
# 2018-01-11 -0.001077  0.007145 -0.005430  0.009409  0.005738
# 2018-01-12  0.011643 -0.002838  0.003346 -0.005178  0.010269
# 2018-01-16 -0.011580 -0.010197  0.008425  0.011452 -0.004970
# 2018-01-17  0.025803  0.002875  0.008703  0.020879  0.016572

# %%
my_portfolio_daily_returns.isnull().sum()
# Out:
# SHOP    0
# OTEX    0
# L       0
# TSLA    0
# AAPL    0
# dtype: int64

# %%
my_portfolio_daily_returns.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/5, 1/5, 1/5, 1/5, 1/5]

# Calculate portfolio return
weighted_returns = my_portfolio_daily_returns.dot(weights)

# Display sample data
weighted_returns.head(10)
# Out:
# Date
# 2018-01-03   -0.001720
# 2018-01-04    0.001969
# 2018-01-05    0.001661
# 2018-01-08    0.011178
# 2018-01-09   -0.002250
# 2018-01-10    0.000930
# 2018-01-11    0.003157
# 2018-01-12    0.003449
# 2018-01-16   -0.001374
# 2018-01-17    0.014967
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
portfolios_returns = pd.concat([combined_returns, weighted_returns], axis="columns", join="inner")
portfolios_returns.rename(columns={0:"My Portfolio"}, inplace=True)
portfolios_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-01-03                   0.004658            0.000027
# 2018-01-04                  -0.000914            0.004196
# 2018-01-05                   0.004072            0.000823
# 2018-01-08                   0.004473           -0.003739
# 2018-01-09                  -0.001028            0.000872
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-01-03                     0.001979                0.005676 -0.000890
# 2018-01-04                     0.010743                0.004065 -0.000914
# 2018-01-05                     0.000737                0.022023 -0.003839
# 2018-01-08                     0.005085                0.003435  0.001653
# 2018-01-09                     0.001789                0.000708 -0.001004
#
#               Algo 2  S&P/TSX60  My Portfolio
# Date
# 2018-01-03  0.008175   0.003774     -0.001720
# 2018-01-04  0.004294   0.002528      0.001969
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
portfolios_returns.dropna()
portfolios_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# S&P/TSX60                      0
# My Portfolio                   0
# dtype: int64

# %%
# Cumulative returns that includes 'My Portforlio'
portfolios_cumulative_returns = (1+portfolios_returns).cumprod()
portfolios_cumulative_returns.plot(figsize=(13,7), title="Cumulative Returns")
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns'}, xlabel='Date'>

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
portfolios_std = portfolios_returns.std()
portfolios_annual_std = portfolios_std * np.sqrt(252)
portfolios_annual_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.145675
# PAULSON & CO.INC.              0.114343
# TIGER GLOBAL MANAGEMENT LLC    0.219833
# BERKSHIRE HATHAWAY INC         0.227445
# Algo 1                         0.120028
# Algo 2                         0.137664
# S&P/TSX60                      0.099121
# My Portfolio                   0.231714
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
portfolios_rolling_std = portfolios_returns.rolling(window=21).std()
# Plot rolling standard deviation
portfolios_rolling_std.plot(figsize=(20,10)).legend(prop={'size': 13})

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
portfolios_correlation = portfolios_returns.corr()
portfolios_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.764174
# PAULSON & CO.INC.                             0.764174            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.526710            0.536534
# BERKSHIRE HATHAWAY INC                        0.782414            0.647407
# Algo 1                                        0.305525            0.320568
# Algo 2                                        0.834431            0.797494
# S&P/TSX60                                     0.686681            0.623728
# My Portfolio                                  0.613105            0.454969
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.526710
# PAULSON & CO.INC.                               0.536534
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.384316
# ...

# %%
sns.heatmap(portfolios_correlation, vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta
my_portfolio_rolling_cov = portfolios_returns["My Portfolio"].rolling(window=60).cov(portfolios_returns["S&P/TSX60"])

my_portfolio_rolling_beta = my_portfolio_rolling_cov / rolling_tsx_variance

my_portfolio_rolling_beta.plot(figsize=(8,5), title="60-Day Rolling Beta: My Portfolio")
# Out:
# <AxesSubplot:title={'center':'60-Day Rolling Beta: My Portfolio'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
portfolios_annual_avg_return = portfolios_returns.mean()*252
portfolios_annual_sharpe = portfolios_annual_avg_return / portfolios_annual_std

# %%
# Visualize the sharpe ratios as a bar plot
portfolios_annual_sharpe.plot(kind="bar", title="Annualized Sharpe Ratio")
# Out:
# <AxesSubplot:title={'center':'Annualized Sharpe Ratio'}>

# %%
portfolios_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.009177
# PAULSON & CO.INC.              0.007203
# TIGER GLOBAL MANAGEMENT LLC    0.013848
# BERKSHIRE HATHAWAY INC         0.014328
# Algo 1                         0.007561
# Algo 2                         0.008672
# S&P/TSX60                      0.006244
# My Portfolio                   0.014597
# dtype: float64

# %%
portfolios_annual_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.145675
# PAULSON & CO.INC.              0.114343
# TIGER GLOBAL MANAGEMENT LLC    0.219833
# BERKSHIRE HATHAWAY INC         0.227445
# Algo 1                         0.120028
# Algo 2                         0.137664
# S&P/TSX60                      0.099121
# My Portfolio                   0.231714
# dtype: float64

# %%
beta_min = my_portfolio_rolling_beta.min()
beta_max = my_portfolio_rolling_beta.max()
beta_avg = my_portfolio_rolling_beta.mean()

print(beta_min)
print(beta_max)
print(beta_avg)
# Out:
# 0.660702931844683
# 1.8665927245455374
# 1.3365208654953171

# %%
portfolios_annual_sharpe
# Out:
# SOROS FUND MANAGEMENT LLC     -0.088196
# PAULSON & CO.INC.             -0.396282
# TIGER GLOBAL MANAGEMENT LLC   -1.391612
# BERKSHIRE HATHAWAY INC         0.195907
# Algo 1                         1.901461
# Algo 2                         0.021394
# S&P/TSX60                      0.034651
# My Portfolio                   1.029485
# dtype: float64

# %% [markdown]
# ### How does your portfolio do?

# %% [markdown]
# My Portfolio has a strong positive correlation to the market(S&P TSX 60) with a value of 0.59, fourth to Berkshire Hathaway Inc. at 0.7118.
#
# The Annualized Standard Deviation and Beta illustrates that it is more volatile, hence riskier, than the overall market. Through the span of the portfolio, the Beta ranged between a min 0.6607 and max of 1.8666. The average Beta of My Portfolio is 1.3365. With that extra risk, we could expect greater returns than what the S&P TSX could perfomr. We get an Annualized Sharpe Ratio of 1.029, lower than that of Harold's Algo 1 strategy(1.90) but a lot better than the other portfolios.
#
# Overall, My Portfolio outperforms majority of whale porfolios and the market, having greater return for the risk that it carries. Algo 1 is a lot less volatile with an Annualized Standard Deviation of 0.120028. The difference in risk may explain why My Portfolio has the least correlation with Algo 1. As an investor, Algo 1 is a better portfolio to invest in because it has less risk than My Portfolio but gives the greatest potential return adjusted for risk out of all portfolios.
